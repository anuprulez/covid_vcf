# %%
import pandas as pd
import numpy as np

# %%
boston_all_path = "../data/outputs/Boston/all/"
pre_cog_uk_all_path = "../data/outputs/Pre-COG-UK/all/"
post_cog_uk_all_path = "../data/outputs/Post-COG-UK/all/"

# %%
boston_merged_cluster_path = boston_all_path + "merged_clusters_of_mutations.csv"
pre_coguk_merged_cluster_path = pre_cog_uk_all_path + "merged_clusters_of_mutations.csv"
post_coguk_merged_cluster_path = post_cog_uk_all_path + "merged_clusters_of_mutations.csv"

boston_same_pos_path = boston_all_path + "same_pos_diff_ref_alt.csv"
pre_coguk_same_pos_path = pre_cog_uk_all_path + "same_pos_diff_ref_alt.csv"
post_coguk_same_pos_path = post_cog_uk_all_path + "same_pos_diff_ref_alt.csv"

# %%
df_boston_mc = pd.read_csv(boston_merged_cluster_path)
df_boston_mc = df_boston_mc.sort_values(by=["POS"])
df_boston_mc.to_csv(boston_merged_cluster_path)

# %%
df_boston_mc
# Out:
#       Unnamed: 0          REF    POS ALT     MinAF     MaxAF  NumSamples  \
# 0              0            T     13   C  0.423077  0.902439           3
# 1              1            C     19   T  0.666667  0.666667           1
# 2              2            C     20   T  0.556610  0.556610           1
# 3              3            C     21   T  0.700000  0.700000           1
# 4              4            C     36   T  0.616667  0.616667           1
# ...          ...          ...    ...  ..       ...       ...         ...
# 1022        1022  CAGTGAACAAT  29762   C  0.107847  0.107847           1
# 1023        1023            C  29769   T  0.928144  0.968791           9
# 1024        1024            G  29773   T  0.930851  0.930851           1
# 1025        1025            C  29774   T  0.111266  0.974948           4
# 1026        1026            A  29806   T  0.889474  0.938776           5
#
#                                             SampleNames  MutationCluster
# ...

# %%
df_pre_coguk_mc = pd.read_csv(pre_coguk_merged_cluster_path)
df_pre_coguk_mc = df_pre_coguk_mc.sort_values(by=["POS"])
df_pre_coguk_mc.to_csv(pre_coguk_merged_cluster_path)

# %%
df_pre_coguk_mc
# Out:
#       Unnamed: 0 REF    POS ALT     MinAF     MaxAF  NumSamples  \
# 0              0   A     31   C  0.202614  0.812500          51
# 1              1   T     65   C  0.062872  0.062872           1
# 2              2   C     66   T  0.096741  0.096741           1
# 3              3   C     71   A  0.060574  0.207792           3
# 4              4   G     72   A  0.057241  0.500000           4
# ...          ...  ..    ...  ..       ...       ...         ...
# 2742        2742   C  29774   T  0.395344  0.957647           2
# 2743        2743   G  29779   T  0.186335  0.186335           1
# 2744        2744   G  29781   T  0.062731  0.062731           1
# 2745        2745   C  29831   T  0.926984  0.926984           1
# 2746        2746   T  29867   A  0.089286  1.000000          93
#
#                                             SampleNames  MutationCluster
# 0     ERR4603984,ERR4604095,ERR4604163,ERR4603842,ER...              148
# ...

# %%
df_post_coguk_mc = pd.read_csv(post_coguk_merged_cluster_path)
df_post_coguk_mc = df_post_coguk_mc.sort_values(by=["POS"])
df_post_coguk_mc.to_csv(post_coguk_merged_cluster_path)

# %%
df_post_coguk_mc
# Out:
#       Unnamed: 0 REF    POS ALT     MinAF     MaxAF  NumSamples  \
# 0              0   C     21   T  0.925373  0.925373           1
# 1              1   G     61   T  0.941959  0.941985           2
# 2              2   T     65   C  0.397059  0.397059           1
# 3              3   C     66   T  0.202791  1.000000         118
# 4              4   T     67   C  0.109424  0.109424           1
# ...          ...  ..    ...  ..       ...       ...         ...
# 5755        5755  TG  29829   T  0.070175  0.070175           1
# 5756        5756   C  29831   T  0.953546  0.965417           2
# 5757        5757   A  29833   G  0.965009  0.977866           2
# 5758        5758   C  29835   T  0.073514  0.389194           2
# 5759        5759   T  29867   A  0.846154  0.846154           1
#
#                                             SampleNames  MutationCluster
# 0                                            ERR4861086            -1054
# ...

# %%
df_boston_spos = pd.read_csv(boston_same_pos_path)
df_pre_coguk_spos = pd.read_csv(pre_coguk_same_pos_path)
df_post_coguk_spos = pd.read_csv(post_coguk_same_pos_path)

# %%
df_boston_spos
# Out:
#                  REF    POS ALT     MinAF     MaxAF  NumSamples  \
# 0                  G    160   T  0.050109  0.150000          54
# 1                  G    160   A  0.815951  0.815951           1
# 2                  A    507   C  0.128015  0.128015           1
# 3   ATGGTCATGTTATGGT    507   A  0.780220  0.780220           1
# 4                  C   3773   T  0.068264  0.068264           1
# 5                  C   3773   A  0.065388  0.065388           1
# 6                  G   7393   T  1.000000  1.000000           1
# 7                  G   7393   A  0.062937  0.062937           1
# 8                  G  21569   T  0.916024  0.916024           1
# 9                  G  21569  GT  0.068630  0.068630           1
# 10                 C  21658   G  0.134054  0.885191           5
# 11                 C  21658   T  0.772321  0.772321           1
# 12                 G  21724   C  0.807229  0.846707           2
# 13                 G  21724   T  0.905213  0.905213           1
# ...

# %%
df_pre_coguk_spos
# Out:
#                   REF    POS ALT     MinAF     MaxAF  NumSamples  \
# 0                  GT    443   G  0.085251  0.085251           1
# 1                   G    443   T  0.098352  0.098352           1
# 2                   A    507   G  0.914509  0.914509           1
# 3    ATGGTCATGTTATGGT    507   A  0.059568  0.665116          10
# 4     GGTCATGTTATGGTT    509   G  0.062306  0.666274           4
# ..                ...    ...  ..       ...       ...         ...
# 315              ATTT  29725   A  0.059066  0.059066           1
# 316                 G  29742   A  0.080501  0.925214          13
# 317                 G  29742   T  0.055256  0.925974           3
# 318                 C  29750   A  0.132812  0.132812           1
# 319                 C  29750   T  0.943838  0.943838           1
#
#                                            SampleNames  MutationCluster
# 0                                           ERR4603894            -1213
# ...

# %%
df_post_coguk_spos
# Out:
#              REF    POS ALT     MinAF     MaxAF  NumSamples  \
# 0              G     72   A  0.059891  0.214286           4
# 1              G     72   T  0.065657  0.065657           1
# 2              C     75  CT  0.088889  0.088889           1
# 3              C     75   T  0.062201  0.375000           2
# 4              C    186   T  0.239756  0.943990           2
# ..           ...    ...  ..       ...       ...         ...
# 831            G  29764   A  0.065033  0.820762           2
# 832  GAACAATGCTA  29766   G  0.997713  0.998418           2
# 833            G  29766   T  0.915825  0.915825           1
# 834            A  29771   G  0.105322  1.000000          58
# 835            A  29771   T  0.873737  0.873737           1
#
#                                            SampleNames  MutationCluster
# 0          ERR4860278,ERR4861148,ERR4859764,ERR4861207             1833
# 1                                           ERR4860920            -1879
# ...

# %%
def find_common_mutations(source, destination):
    s_pos = list()
    common_df = None
    for i in range(len(source)):
        row = source.take([i])
        source_pos = row["POS"].values[0]
        if source_pos not in s_pos:
            s_pos.append(source_pos)
            source_rows = source[source["POS"] == source_pos]
            destination_rows = destination[destination["POS"] == source_pos]
            if len(destination_rows) > 1:
                source_rows["Dataset_Name"] = np.repeat("POST-COG-UK", len(source_rows))
                destination_rows["Dataset_Name"] = np.repeat("PRE-COG-UK", len(destination_rows))
                if common_df is None:
                    common_df = pd.concat([source_rows, destination_rows], ignore_index=True)
                else:
                    common_df = pd.concat([common_df, source_rows], ignore_index=True)
                    common_df = pd.concat([common_df, destination_rows], ignore_index=True)
    common_df.to_csv("../data/outputs/Common/same_pos_pre_post_cog_uk.csv", index=False)
         
find_common_mutations(df_pre_coguk_spos, df_post_coguk_spos)        # df_pre_coguk_spos df_post_coguk_spos df_boston_spos
# Out:
# /home/kumara/miniconda3/envs/covid_vcf/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /home/kumara/miniconda3/envs/covid_vcf/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/kumara/miniconda3/envs/covid_vcf/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# ...

# %%
def find_common_mutations_mc():
    max_pos = 30000
    common_df = None
    for i in range(max_pos):
        try:        
            POS = str(i)
            boston_rows = df_boston_mc[df_boston_mc["POS"] == i]
            pre_rows = df_pre_coguk_mc[df_pre_coguk_mc["POS"] == i]
            post_rows = df_post_coguk_mc[df_post_coguk_mc["POS"] == i]
            
            if len(boston_rows) > 0 and len(pre_rows) > 0 and len(post_rows) > 0: 
                #print("Present POS: {}".format(POS))
                boston_rows["Dataset_Name"] = np.repeat("Boston", len(boston_rows))
                pre_rows["Dataset_Name"] = np.repeat("PRE-COG-UK", len(pre_rows))
                post_rows["Dataset_Name"] = np.repeat("POST-COG-UK", len(post_rows))
                
                if common_df is None:
                    common_df = pd.concat([boston_rows, pre_rows], ignore_index=True)
                    common_df = pd.concat([common_df, post_rows], ignore_index=True)
                else:
                    common_df = pd.concat([common_df, boston_rows], ignore_index=True)
                    common_df = pd.concat([common_df, pre_rows], ignore_index=True)
                    common_df = pd.concat([common_df, post_rows], ignore_index=True)
        except Exception:
            print("POS {} not present in all three datasets".format(str(i)))
    common_df.to_csv("../data/outputs/Common/common_pos_mc_boston_pre_post_cog_uk.csv", index=False)

# %%
find_common_mutations_mc()
# Out:
# /home/kumara/miniconda3/envs/covid_vcf/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/kumara/miniconda3/envs/covid_vcf/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/kumara/miniconda3/envs/covid_vcf/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
def find_common_mutations_mc_pre_post():
    max_pos = 30000
    common_df = None
    for i in range(max_pos):
        try:        
            POS = str(i)
            pre_rows = df_pre_coguk_mc[df_pre_coguk_mc["POS"] == i]
            post_rows = df_post_coguk_mc[df_post_coguk_mc["POS"] == i]
            
            if len(pre_rows) > 0 and len(post_rows) > 0: 
                print("Present POS: {}".format(POS))
                pre_rows["Dataset_Name"] = np.repeat("PRE-COG-UK", len(pre_rows))
                post_rows["Dataset_Name"] = np.repeat("POST-COG-UK", len(post_rows))
                
                if common_df is None:
                    common_df = pd.concat([pre_rows, post_rows], ignore_index=True)
                else:
                    common_df = pd.concat([common_df, pre_rows], ignore_index=True)
                    common_df = pd.concat([common_df, post_rows], ignore_index=True)
        except Exception:
            print("POS {} not present in pre and post cog uk datasets".format(str(i)))
    common_df.to_csv("../data/outputs/Common/common_pos_mc_pre_post_cog_uk.csv")

# %%
find_common_mutations_mc_pre_post()
# Out:
# Present POS: 65
# Present POS: 66
# Present POS: 71
# Present POS: 72
# Present POS: 103
# Present POS: 106
# /home/kumara/miniconda3/envs/covid_vcf/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /home/kumara/miniconda3/envs/covid_vcf/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# ...
